# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/Users/aishwaryakompella/Downloads/2301 Week 6 Coding Demo 1-Student/College_Employment_Competitiveness.csv")

# shows first 5 rows 
df.head()
# Out:
#     GPA  Credits_Completed  Exam_Scores  Attendance_Percentage  Coding_Skills  \
# 0  2.75                125           99                  93.02              9
# 1  3.90                 40           80                  77.11              5
# 2  3.46                 83           82                  84.48              8
# 3  3.20                 46           96                  73.47              7
# 4  2.31                 74           67                  71.98              9
#
#    Communication_Skills  Leadership_Skills  Clubs_Joined  Events_Participated  \
# 0                     9                  3             2                    1
# 1                     8                  1             2                    8
# 2                     2                  3             1                    1
# 3                     9                  1             0                    4
# 4                     2                  9             1                    2
#
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           4000 non-null   float64
#  1   Credits_Completed             4000 non-null   int64
#  2   Exam_Scores                   4000 non-null   int64
#  3   Attendance_Percentage         4000 non-null   float64
#  4   Coding_Skills                 4000 non-null   int64
#  5   Communication_Skills          4000 non-null   int64
#  6   Leadership_Skills             4000 non-null   int64
#  7   Clubs_Joined                  4000 non-null   int64
#  8   Events_Participated           4000 non-null   int64
#  9   Internship_Completed          4000 non-null   int64
#  10  Internship_Duration_Months    4000 non-null   int64
#  11  Library_Visits_Per_Week       4000 non-null   int64
#  12  Online_Course_Hours_Per_Week  4000 non-null   int64
# ...

# %%
df["Employment_Competitiveness"].value_counts()
# Out:
# Employment_Competitiveness
# High      1334
# Medium    1333
# Low       1333
# Name: count, dtype: int64

# %%
order = ["Low", "Medium", "High"]

df["Employment_Competitiveness"] = pd.Categorical(
    df["Employment_Competitiveness"],
    categories=order,
    ordered=True
)

# %%
sns.countplot(data=df, x="Employment_Competitiveness", order=order)
plt.title("Distribution of Employment Competitiveness")
plt.xlabel("Competitiveness Level")
plt.ylabel("Count")
plt.show()

# %%
sns.boxplot(
    data=df,
    x="Employment_Competitiveness",
    y="GPA",
    order=order
)

plt.title("GPA Distribution by Employment Competitiveness")
plt.xlabel("Competitiveness Level")
plt.ylabel("GPA")
plt.show()

# %%
sns.boxplot(
    data=df,
    x="Employment_Competitiveness",
    y="Exam_Scores",
    order=order
)

plt.title("Exam Scores by Employment Competitiveness")
plt.xlabel("Competitiveness Level")
plt.ylabel("Exam Scores")
plt.show()

# %%
sns.pairplot(
    df[["GPA", "Exam_Scores", "Employment_Competitiveness"]],
    hue="Employment_Competitiveness"
)

plt.show()

# %%
# confirming the that there is no corrolation/ randomness of the dataset based on the graphs 
df[["GPA", "Exam_Scores"]].corr()
# Out:
#                   GPA  Exam_Scores
# GPA          1.000000    -0.008226
# Exam_Scores -0.008226     1.000000
